# %% [markdown]
# ## 2. LIMPIEZA Y TRANSFORMACIÓN
#
# - normalización
# - cambio del tipo dato (fecha)
# - eliminar columnas
# - crear nuevas variables

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("data.csv", sep=";", engine="python", skiprows=3)

df.head()
# Out:
#    Campaign ID            Campaign Name Name from       Email from  \
# 0            5  Resumen Webinar enGira!   enGira!  info@engira.art
# 1            6        Artistas Catálogo   enGira!  info@engira.art
# 2            8   Artistas seleccionados   enGira!  info@engira.art
# 3           10         ARTISTAS TOOLKIT   enGira!  info@engira.art
# 4           12             Recordatorio   enGira!  info@engira.art
#
#   Sending date                        Subject  Sent  Non delivered  \
# 0   04-12-2024        Resumen Webinar enGira!   103              0
# 1   23-10-2024   Participación Piloto enGira!     3              0
# 2   29-10-2024         Artistas seleccionados    38              2
# 3   28-10-2024  Participación Piloto enGira​!   122              5
# 4   29-10-2024   Participación Piloto enGira!    24              1
#
#    Hard bounces  Soft bounces Non delivered rate  Delivered  Total opens  \
# 0             0             0                 0%        103          247
# 1             0             0                 0%          3           13
# 2             0             2              5,26%         36          773
# 3             2             3              4,10%        117          974
# 4             0             1              4,17%         23          214
#
#    Opens Trackable open rate  Apple MPP Opens  Total clicked  Clicked  \
# 0     87              84,47%               19             34       19
# 1      3                100%                0              3        1
# 2     44                100%                9             99       32
# 3    134                100%               33            199       70
# 4     27                100%                5             25       12
#
#   Click rate Click-to-Open rate  Unsubscribed Unsubscription rate  \
# 0     18,45%             27,94%             0                  0%
# 1     33,33%             33,33%             0                  0%
# 2     88,89%             91,43%             0                  0%
# 3     59,83%             69,31%             0                  0%
# 4     52,17%             54,55%             0                  0%
#
#   Delivered rate Hard Bounces rate Soft Bounces rate  Complaints  \
# 0           100%                0%                0%           0
# 1           100%                0%                0%           0
# 2         94,74%                0%             5,26%           0
# 3         95,90%             1,64%             2,46%           1
# 4         95,83%                0%             4,17%           0
#
#   Complaints rate
# 0              0%
# 1              0%
# 2              0%
# 3           0,82%
# 4              0%

# %%
df = df.drop(columns=[
    "Name from", "Email from", "Hard bounces", 
    "Soft bounces", "Non delivered", "Delivered", 
    "Unsubscribed", "Complaints"])

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df['sending_date'] = pd.to_datetime(df["sending_date"], errors="coerce")

# %%
df['sending_date'].dtype
# Out:
# dtype('<M8[us]')

# %%
df['year'] = df['sending_date'].dt.year
df['month'] = df['sending_date'].dt.month
df['day'] = df['sending_date'].dt.day
df['weekday'] = df['sending_date'].dt.weekday

# %%
df['subject'].value_counts()
# Out:
# subject
# Nuevas convocatorias                                            7
# Programa Piloto enGira!                                         4
# Demo enGira!                                                    4
# Participación Piloto enGira!                                    2
# Fin del Programa Piloto enGira!​                                2
# Descubre nuevos artistas escénicos                              2
# Presentes en dFeria                                             2
# Presentamos enGira! en Madferia                                 2
# Resumen Webinar enGira!                                         1
# Artistas seleccionados                                          1
# Participación Piloto enGira​!                                   1
# Jornadas enGira!                                                1
# No te pierdas estas Convocatorias!                              1
# Webinar enGira! 3 de diciembre                                  1
# Jornadas de Internacionalización y Movilidad de Artistas!       1
# Artista destacado                                               1
# Jornadas de Internacionalización y Movilidad de artistas        1
# Invitación Piloto enGira!                                       1
# Recordatorio Webinar enGira!                                    1
# Nuevas Convocatorias!                                           1
# Convocatorias abiertas                                          1
# Descubre artistas y conecta con ellos                           1
# Descubre nuevos artistas escénicos de creación contemporánea    1
# Descobreix nous artistes escènics de creació contemporània      1
# Nuevas convocatorias y una "demo"                               1
# Te ayudamos a completar el registro?                            1
# Échale un vistazo a estas convocatorias                         1
# ¡Gracias por acompañarnos en la presentación de enGira!         1
# enGira! | MERCARTES 2025                                        1
# enGira! | Terminar registro                                     1
# enGira! | ¡Nos vemos en MERCARTES 2025!                         1
# enGira! - Stand 241 de MERCARTES                                1
# Nuevas Convocatorias y Programas de Acompañamiento              1
# Invitación al Webinar enGira!                                   1
# Grabación Webinar y Plan de Acompañamiento                      1
# Últimas convocatorias del año                                   1
# Nuevo año, nuevas convocatorias                                 1
# Name: count, dtype: int64

# %%
df['subject'] = df['subject'].str.lower().str.strip()

# %%
def clasificar_campaña(nombre):
    
    if "convocatorias" in nombre:
        return "convocatorias"
    
    elif "jornadas" in nombre:
        return "jornadas"
    
    elif "demo" in nombre or 'webinar' in nombre or 'registro' in nombre:
        return "formacion"
    
    elif "dferia" in nombre or 'madferia' in nombre or 'mercartes' in nombre:
        return "ferias"
    
    elif "descubre" in nombre or "descobreix" in nombre or 'funcionamiento' in nombre or 'piloto' in nombre or 'destacados' in nombre:
        return "promocion"
    
    else:
        return "otros"

# %%
df['tipo_campaña'] = df['subject'].apply(clasificar_campaña)

# %%
df['tipo_campaña'].value_counts()
# Out:
# tipo_campaña
# promocion        15
# convocatorias    15
# formacion        11
# ferias            7
# otros             3
# jornadas          3
# Name: count, dtype: int64

# %%
df['campaign_name'] = df['campaign_name'].str.lower().str.strip()

# %%
def clasificar_publico(nombre):
    
    if 'artistas' in nombre or 'convocatorias' in nombre or 'webinar' in nombre or 'diagnostico'in nombre:
        
        return 'artistas'
    
    elif 'programadores' in nombre or 'demo' in nombre:
        
        return 'programadores'
    
    else:
        return 'all'

# %%
df['tipo_publico'] = df['campaign_name'].apply(clasificar_publico)

# %%
df['tipo_publico'].value_counts()
# Out:
# tipo_publico
# artistas         27
# programadores    16
# all              11
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['campaign_id', 'campaign_name', 'sending_date', 'subject', 'sent',
#        'non_delivered_rate', 'total_opens', 'opens', 'trackable_open_rate',
#        'apple_mpp_opens', 'total_clicked', 'clicked', 'click_rate',
#        'click-to-open_rate', 'unsubscription_rate', 'delivered_rate',
#        'hard_bounces_rate', 'soft_bounces_rate', 'complaints_rate', 'year',
#        'month', 'day', 'weekday', 'tipo_campaña', 'tipo_publico'],
#       dtype='str')
